# %%
list1 = list("hELLO pYTHON")
print(list1)
print(len(list1))
# Out:
# ['h', 'E', 'L', 'L', 'O', ' ', 'p', 'Y', 'T', 'H', 'O', 'N']
# 12

# %%
my_list = ('Akshat', 'Thakur', 'B.tech', 'CSE', 'Group1', 'Section M', 'Batch of 2026')
print(my_list)
print(len(my_list))
# Out:
# ('Akshat', 'Thakur', 'B.tech', 'CSE', 'Group1', 'Section M', 'Batch of 2026')
# 7

# %%
print(my_list[2:5])
print(my_list[5:7])
print(my_list[-7:-3])
print(my_list[-4:-2])
# Out:
# ('B.tech', 'CSE', 'Group1')
# ('Section M', 'Batch of 2026')
# ('Akshat', 'Thakur', 'B.tech', 'CSE')
# ('CSE', 'Group1')

# %%
print(my_list[1:6:2])
print(my_list[::2])
print(my_list[1::3])
print(my_list[::-1])
# Out:
# ('Thakur', 'CSE', 'Section M')
# ('Akshat', 'B.tech', 'Group1', 'Batch of 2026')
# ('Thakur', 'Group1')
# ('Batch of 2026', 'Section M', 'Group1', 'CSE', 'B.tech', 'Thakur', 'Akshat')

# %%
my_list.sort()
print(my_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-3f28988e4cbc> in <cell line: 1>()
# ----> 1 my_list.sort()
#       2 print(my_list)
#
# AttributeError: 'tuple' object has no attribute 'sort'

# %%
squaredNum= []
for i in range(1,11):
    squaredNum.append(i*i)
print(squaredNum)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
squaredNumber = [i*i for i in range(1,11)]  #List Comprehension
print(squaredNumber)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
